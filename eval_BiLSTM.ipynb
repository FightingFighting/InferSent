# %%
import os
from torchtext import data
import torch
import torch.nn as nn
import torch.optim as optim
import senteval
import numpy as np
from torchtext.datasets import SNLI
from torchtext.vocab import GloVe
from model.NLINet import NLINet
import logging
logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.DEBUG)

# %%
# build dataset and word embedding

glove = GloVe(name='840B', dim=300, cache="./dataset/.vector_cache")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#set up fields
text_field = data.Field(tokenize='spacy',tokenizer_language="en_core_web_sm",
                        lower=True,include_lengths=True,batch_first=True)
label_field = data.Field(sequential=False)

train, val, test = SNLI.splits(text_field, label_field, root="./dataset/.data")

# build vocab
text_field.build_vocab(train, vectors=glove)
label_field.build_vocab(train)
vocabulary = text_field.vocab

train_iters,val_iters,test_iters = data.BucketIterator.splits(
    (train, val, test), batch_size=128, device=device)
# Out:
# 2021-04-22 21:08:40,463 : Loading vectors from ../my_job/dataset/.vector_cache/glove.840B.300d.txt.pt
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/example.py:13: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/iterator.py:48: UserWarning: BucketIterator class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)

# %%
def eval_SentEval(NLINet_model,vocabulary,text_field,device):
    logging.info("**************Start SentEval evaluation*******************")
    def batcher(params, batch):
        batch = [sent if sent != [] else ['.'] for sent in batch]
        torch.cuda.empty_cache()
        with torch.no_grad():
            batch_pad = params.text_field.process(batch,device=params.device)
            batch, batch_len = batch_pad
            embedding_glove = params.NLINet_model.embedding(batch)
            embeddings_sents = params.NLINet_model.encoder_model(embedding_glove,batch_len)
            embeddings_sents = embeddings_sents.cpu().numpy()
        return embeddings_sents

    # parameters
    params = {'task_path': "./SentEval/data", 'usepytorch': True, 'kfold': 10,'batch_size': 256}
    params['classifier'] = {'nhid': 0, 'optim': 'adam', 'batch_size': 256,
                            'tenacity': 5, 'epoch_size': 4}

    params["word2id"] = vocabulary.stoi
    params["word_vec"] = vocabulary.vectors
    params["wvec_dim"] = 300
    params["NLINet_model"] = NLINet_model
    params["text_field"] = text_field
    params["device"] = device

    se = senteval.engine.SE(params, batcher)
    transfer_tasks = ['CR','MR', 'SUBJ', 'MPQA', 'SST2', 'TREC',
                      'SICKRelatedness', 'SICKEntailment', 'MRPC', 'STS14']

    results = se.eval(transfer_tasks)

    logging.info("SentEval evalution_results:", results)
    logging.info('********************SentEval evaluation completed*************************')
    
def eval_SNLI(NLINet_model,test_iters):
    logging.info("***********************Start SNLI evaluation*******************************")
    eval_acc = 0
    for j, batch in enumerate(test_iters):
        hypothesis = batch.hypothesis
        premise = batch.premise
        labels = batch.label-1

        # forward + backward + optimize
        preds = NLINet_model(hypothesis, premise)
        eval_acc += binary_acc(preds, labels).item()

    eval_acc = eval_acc/len(test_iters.dataset.examples)
    logging.info(f"SNLI evalution_accuracy: {eval_acc:.5f}")
    logging.info("***************SNLI evaluation completed********************")
    
def binary_acc(preds, y):
    """
    get accuracy
    """
    preds = torch.argmax(preds, dim=1)
    correct = torch.eq(preds, y).float()
    acc = correct.sum()
    return acc

# %%
# load BiLSTM model 
BiLSTM_model_path = os.path.join('./output/BiLSTM', "models", 'best_checkpoint.pkl')
NLINet_BiLSTM_model=torch.load(BiLSTM_model_path)
NLINet_BiLSTM_model.eval()
# Out:
# NLINet(
#   (embedding): Embedding(33635, 300)
#   (encoder_model): BiLSTM(
#     (lstm): LSTM(300, 2048, batch_first=True, bidirectional=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
# evaluate BiLSTM model by SNLI
eval_SNLI(NLINet_BiLSTM_model,test_iters)
# Out:
# 2021-04-22 21:09:38,575 : ***********************Start SNLI evaluation*******************************
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/batch.py:23: UserWarning: Batch class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# 2021-04-22 21:09:54,318 : SNLI evalution_accuracy: 0.84019
# 2021-04-22 21:09:54,319 : ***************SNLI evaluation completed********************

# %%
# evaluate BiLSTM model by SentEval
eval_SentEval(NLINet_BiLSTM_model,vocabulary,text_field,device)
# Out:
# 2021-04-22 21:09:54,324 : **************Start SentEval evaluation*******************
# 2021-04-22 21:09:54,325 : ***** Transfer task : CR *****
#
#
# 2021-04-22 21:09:54,337 : Generating sentence embeddings
# 2021-04-22 21:09:58,204 : Generated sentence embeddings
# 2021-04-22 21:09:58,205 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:10:34,318 : Best param found at split 1: l2reg = 1e-05                 with score 81.37
# 2021-04-22 21:11:12,049 : Best param found at split 2: l2reg = 1e-05                 with score 81.93
# 2021-04-22 21:11:48,818 : Best param found at split 3: l2reg = 1e-05                 with score 81.01
# 2021-04-22 21:12:27,683 : Best param found at split 4: l2reg = 0.0001                 with score 81.28
# 2021-04-22 21:13:02,736 : Best param found at split 5: l2reg = 0.0001                 with score 81.22
# 2021-04-22 21:13:40,754 : Best param found at split 6: l2reg = 1e-05                 with score 81.05
# 2021-04-22 21:14:18,477 : Best param found at split 7: l2reg = 1e-05                 with score 81.02
# 2021-04-22 21:14:56,230 : Best param found at split 8: l2reg = 1e-05                 with score 81.16
# 2021-04-22 21:15:37,665 : Best param found at split 9: l2reg = 0.0001                 with score 80.9
# 2021-04-22 21:16:15,216 : Best param found at split 10: l2reg = 1e-05                 with score 81.25
# 2021-04-22 21:16:16,141 : Dev acc : 81.22 Test acc : 80.64
#
# 2021-04-22 21:16:16,143 : ***** Transfer task : MR *****
#
#
# 2021-04-22 21:16:16,184 : Generating sentence embeddings
# 2021-04-22 21:16:27,116 : Generated sentence embeddings
# 2021-04-22 21:16:27,118 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:18:05,892 : Best param found at split 1: l2reg = 0.0001                 with score 76.27
# 2021-04-22 21:19:39,972 : Best param found at split 2: l2reg = 1e-05                 with score 76.11
# 2021-04-22 21:21:20,151 : Best param found at split 3: l2reg = 1e-05                 with score 75.75
# 2021-04-22 21:22:50,419 : Best param found at split 4: l2reg = 0.0001                 with score 75.41
# 2021-04-22 21:24:27,838 : Best param found at split 5: l2reg = 1e-05                 with score 76.06
# 2021-04-22 21:25:57,636 : Best param found at split 6: l2reg = 1e-05                 with score 75.85
# 2021-04-22 21:27:35,864 : Best param found at split 7: l2reg = 0.0001                 with score 75.75
# 2021-04-22 21:29:12,667 : Best param found at split 8: l2reg = 1e-05                 with score 75.42
# 2021-04-22 21:30:47,163 : Best param found at split 9: l2reg = 1e-05                 with score 75.94
# 2021-04-22 21:32:22,378 : Best param found at split 10: l2reg = 1e-05                 with score 75.71
# 2021-04-22 21:32:24,690 : Dev acc : 75.83 Test acc : 74.99
#
# 2021-04-22 21:32:24,692 : ***** Transfer task : SUBJ *****
#
#
# 2021-04-22 21:32:24,731 : Generating sentence embeddings
# 2021-04-22 21:32:35,835 : Generated sentence embeddings
# 2021-04-22 21:32:35,836 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:34:17,137 : Best param found at split 1: l2reg = 1e-05                 with score 91.26
# 2021-04-22 21:36:00,440 : Best param found at split 2: l2reg = 1e-05                 with score 91.26
# 2021-04-22 21:37:40,582 : Best param found at split 3: l2reg = 1e-05                 with score 91.28
# 2021-04-22 21:39:20,463 : Best param found at split 4: l2reg = 1e-05                 with score 91.07
# 2021-04-22 21:41:00,949 : Best param found at split 5: l2reg = 1e-05                 with score 91.34
# 2021-04-22 21:42:41,070 : Best param found at split 6: l2reg = 1e-05                 with score 91.31
# 2021-04-22 21:44:24,294 : Best param found at split 7: l2reg = 1e-05                 with score 91.4
# 2021-04-22 21:46:09,308 : Best param found at split 8: l2reg = 1e-05                 with score 91.2
# 2021-04-22 21:47:55,716 : Best param found at split 9: l2reg = 1e-05                 with score 91.4
# 2021-04-22 21:49:34,674 : Best param found at split 10: l2reg = 1e-05                 with score 91.14
# 2021-04-22 21:49:37,849 : Dev acc : 91.27 Test acc : 90.75
#
# 2021-04-22 21:49:37,851 : ***** Transfer task : MPQA *****
#
#
# 2021-04-22 21:49:37,869 : Generating sentence embeddings
# 2021-04-22 21:49:42,984 : Generated sentence embeddings
# 2021-04-22 21:49:42,986 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:51:06,699 : Best param found at split 1: l2reg = 0.0001                 with score 86.12
# 2021-04-22 21:52:32,991 : Best param found at split 2: l2reg = 0.0001                 with score 85.91
# 2021-04-22 21:54:05,681 : Best param found at split 3: l2reg = 1e-05                 with score 85.63
# 2021-04-22 21:55:30,750 : Best param found at split 4: l2reg = 1e-05                 with score 85.58
# 2021-04-22 21:56:59,887 : Best param found at split 5: l2reg = 0.0001                 with score 86.01
# 2021-04-22 21:58:31,753 : Best param found at split 6: l2reg = 1e-05                 with score 85.54
# 2021-04-22 22:00:13,680 : Best param found at split 7: l2reg = 0.0001                 with score 85.92
# 2021-04-22 22:01:51,111 : Best param found at split 8: l2reg = 0.0001                 with score 85.82
# 2021-04-22 22:03:19,172 : Best param found at split 9: l2reg = 0.0001                 with score 85.91
# 2021-04-22 22:04:39,700 : Best param found at split 10: l2reg = 0.0001                 with score 85.88
# 2021-04-22 22:04:41,298 : Dev acc : 85.83 Test acc : 85.32
#
# 2021-04-22 22:04:41,300 : ***** Transfer task : SST Binary classification *****
#
#
# 2021-04-22 22:04:41,423 : Computing embedding for train
# 2021-04-22 22:05:10,016 : Computed train embeddings
# 2021-04-22 22:05:10,017 : Computing embedding for dev
# 2021-04-22 22:05:10,675 : Computed dev embeddings
# 2021-04-22 22:05:10,676 : Computing embedding for test
# 2021-04-22 22:05:11,983 : Computed test embeddings
# 2021-04-22 22:05:11,984 : Training pytorch-MLP-nhid0-adam-bs256 with standard validation..
# 2021-04-22 22:05:57,902 : [('reg:1e-05', 80.62), ('reg:0.0001', 80.16), ('reg:0.001', 78.56), ('reg:0.01', 77.41)]
# 2021-04-22 22:05:57,903 : Validation : best param found is reg = 1e-05 with score             80.62
# 2021-04-22 22:05:57,903 : Evaluating...
# 2021-04-22 22:06:11,249 :
# Dev acc : 80.62 Test acc : 79.19 for             SST Binary classification
#
# 2021-04-22 22:06:11,253 : ***** Transfer task : TREC *****
#
#
# 2021-04-22 22:06:13,737 : Computed train embeddings
# 2021-04-22 22:06:13,951 : Computed test embeddings
# 2021-04-22 22:06:13,952 : Training pytorch-MLP-nhid0-adam-bs256 with 10-fold cross-validation
# 2021-04-22 22:07:24,690 : [('reg:1e-05', 74.12), ('reg:0.0001', 73.73), ('reg:0.001', 71.08), ('reg:0.01', 61.79)]
# 2021-04-22 22:07:24,691 : Cross-validation : best param found is reg = 1e-05             with score 74.12
# 2021-04-22 22:07:24,692 : Evaluating...
# 2021-04-22 22:07:26,722 :
# Dev acc : 74.12 Test acc : 76.4             for TREC
#
# 2021-04-22 22:07:26,725 : ***** Transfer task : SICK-Relatedness*****
#
#
# 2021-04-22 22:07:26,755 : Computing embedding for train
# 2021-04-22 22:07:30,873 : Computed train embeddings
# 2021-04-22 22:07:30,874 : Computing embedding for dev
# 2021-04-22 22:07:31,359 : Computed dev embeddings
# 2021-04-22 22:07:31,360 : Computing embedding for test
# 2021-04-22 22:07:35,855 : Computed test embeddings
# 2021-04-22 22:07:59,883 : Dev : Pearson 0.8812843084282838
# 2021-04-22 22:07:59,884 : Test : Pearson 0.8775272165973131 Spearman 0.8163380188196849 MSE 0.23548670893807622                        for SICK Relatedness
#
# 2021-04-22 22:07:59,887 : ***** Transfer task : SICK-Entailment*****
#
#
# 2021-04-22 22:07:59,925 : Computing embedding for train
# 2021-04-22 22:08:04,063 : Computed train embeddings
# 2021-04-22 22:08:04,064 : Computing embedding for dev
# 2021-04-22 22:08:04,545 : Computed dev embeddings
# 2021-04-22 22:08:04,546 : Computing embedding for test
# 2021-04-22 22:08:09,052 : Computed test embeddings
# 2021-04-22 22:08:09,330 : Training pytorch-MLP-nhid0-adam-bs256 with standard validation..
# 2021-04-22 22:08:14,163 : [('reg:1e-05', 83.6), ('reg:0.0001', 83.2), ('reg:0.001', 83.6), ('reg:0.01', 81.0)]
# 2021-04-22 22:08:14,164 : Validation : best param found is reg = 1e-05 with score             83.6
# 2021-04-22 22:08:14,165 : Evaluating...
# 2021-04-22 22:08:15,448 :
# Dev acc : 83.6 Test acc : 83.07 for                        SICK entailment
#
# 2021-04-22 22:08:15,453 : ***** Transfer task : MRPC *****
#
#
# 2021-04-22 22:08:15,493 : Computing embedding for train
# 2021-04-22 22:08:21,228 : Computed train embeddings
# 2021-04-22 22:08:21,229 : Computing embedding for test
# 2021-04-22 22:08:23,295 : Computed test embeddings
# 2021-04-22 22:08:23,456 : Training pytorch-MLP-nhid0-adam-bs256 with 10-fold cross-validation
# 2021-04-22 22:08:52,431 : [('reg:1e-05', 73.6), ('reg:0.0001', 73.92), ('reg:0.001', 73.06), ('reg:0.01', 71.12)]
# 2021-04-22 22:08:52,432 : Cross-validation : best param found is reg = 0.0001             with score 73.92
# 2021-04-22 22:08:52,432 : Evaluating...
# 2021-04-22 22:08:53,212 : Dev acc : 73.92 Test acc 72.87; Test F1 81.52 for MRPC.
#
# 2021-04-22 22:08:53,215 : ***** Transfer task : STS14 *****
#
#
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/sts.py:42: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/sts.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# 2021-04-22 22:08:53,611 : deft-forum : pearson = 0.3398, spearman = 0.3489
# 2021-04-22 22:08:53,993 : deft-news : pearson = 0.6742, spearman = 0.6445
# 2021-04-22 22:08:54,457 : headlines : pearson = 0.5704, spearman = 0.5541
# 2021-04-22 22:08:54,981 : images : pearson = 0.8244, spearman = 0.7828
# 2021-04-22 22:08:55,465 : OnWN : pearson = 0.6763, spearman = 0.7127
# 2021-04-22 22:08:56,071 : tweet-news : pearson = 0.6818, spearman = 0.6408
# 2021-04-22 22:08:56,072 : ALL (weighted average) : Pearson = 0.6453,             Spearman = 0.6315
# 2021-04-22 22:08:56,072 : ALL (average) : Pearson = 0.6278,             Spearman = 0.6140
#
# 2021-04-22 22:08:56,073 : SentEval evalution_results:
# 2021-04-22 22:08:56,073 : ********************SentEval evaluation completed*************************
