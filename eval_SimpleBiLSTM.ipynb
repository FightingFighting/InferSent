# %%
import os
from torchtext import data
import torch
import torch.nn as nn
import torch.optim as optim
import senteval
import numpy as np
from torchtext.datasets import SNLI
from torchtext.vocab import GloVe
from model.NLINet import NLINet
import logging
logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.DEBUG)

# %%
# build dataset and word embedding

glove = GloVe(name='840B', dim=300, cache="./dataset/.vector_cache")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#set up fields
text_field = data.Field(tokenize='spacy',tokenizer_language="en_core_web_sm",
                        lower=True,include_lengths=True,batch_first=True)
label_field = data.Field(sequential=False)

train, val, test = SNLI.splits(text_field, label_field, root="./dataset/.data")

# build vocab
text_field.build_vocab(train, vectors=glove)
label_field.build_vocab(train)
vocabulary = text_field.vocab

train_iters,val_iters,test_iters = data.BucketIterator.splits(
    (train, val, test), batch_size=128, device=device)
# Out:
# 2021-04-22 21:08:33,035 : Loading vectors from ../my_job/dataset/.vector_cache/glove.840B.300d.txt.pt
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/example.py:13: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/iterator.py:48: UserWarning: BucketIterator class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)

# %%
def eval_SentEval(NLINet_model,vocabulary,text_field,device):
    logging.info("**************Start SentEval evaluation*******************")
    def batcher(params, batch):
        batch = [sent if sent != [] else ['.'] for sent in batch]
        torch.cuda.empty_cache()
        with torch.no_grad():
            batch_pad = params.text_field.process(batch,device=params.device)
            batch, batch_len = batch_pad
            embedding_glove = params.NLINet_model.embedding(batch)
            embeddings_sents = params.NLINet_model.encoder_model(embedding_glove,batch_len)
            embeddings_sents = embeddings_sents.cpu().numpy()
        return embeddings_sents

    # parameters
    params = {'task_path': "./SentEval/data", 'usepytorch': True, 'kfold': 10,'batch_size': 256}
    params['classifier'] = {'nhid': 0, 'optim': 'adam', 'batch_size': 256,
                            'tenacity': 5, 'epoch_size': 4}

    params["word2id"] = vocabulary.stoi
    params["word_vec"] = vocabulary.vectors
    params["wvec_dim"] = 300
    params["NLINet_model"] = NLINet_model
    params["text_field"] = text_field
    params["device"] = device

    se = senteval.engine.SE(params, batcher)
    transfer_tasks = ['CR','MR', 'SUBJ', 'MPQA', 'SST2', 'TREC',
                      'SICKRelatedness', 'SICKEntailment', 'MRPC', 'STS14']

    results = se.eval(transfer_tasks)

    logging.info("SentEval evalution_results:", results)
    logging.info('********************SentEval evaluation completed*************************')
    
def eval_SNLI(NLINet_model,test_iters):
    logging.info("***********************Start SNLI evaluation*******************************")
    eval_acc = 0
    for j, batch in enumerate(test_iters):
        hypothesis = batch.hypothesis
        premise = batch.premise
        labels = batch.label-1

        # forward + backward + optimize
        preds = NLINet_model(hypothesis, premise)
        eval_acc += binary_acc(preds, labels).item()

    eval_acc = eval_acc/len(test_iters.dataset.examples)
    logging.info(f"SNLI evalution_accuracy: {eval_acc:.5f}")
    logging.info("***************SNLI evaluation completed********************")
    
def binary_acc(preds, y):
    """
    get accuracy
    """
    preds = torch.argmax(preds, dim=1)
    correct = torch.eq(preds, y).float()
    acc = correct.sum()
    return acc

# %%
# load SimpleBiLSTM model 
SimpleBiLSTM_model_path = os.path.join('./output/SimpleBiLSTM', "models", 'best_checkpoint.pkl')
NLINet_SimpleBiLSTM_model=torch.load(SimpleBiLSTM_model_path)
NLINet_SimpleBiLSTM_model.eval()
# Out:
# NLINet(
#   (embedding): Embedding(33635, 300)
#   (encoder_model): SimpleBiLSTM(
#     (lstm): LSTM(300, 2048, batch_first=True, bidirectional=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
# evaluate SimpleBiLSTM model by SNLI
eval_SNLI(NLINet_SimpleBiLSTM_model,test_iters)
# Out:
# 2021-04-22 21:09:30,105 : ***********************Start SNLI evaluation*******************************
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/batch.py:23: UserWarning: Batch class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# 2021-04-22 21:09:37,390 : SNLI evalution_accuracy: 0.80731
# 2021-04-22 21:09:37,391 : ***************SNLI evaluation completed********************

# %%
# evaluate SimpleBiLSTM model by SentEval
eval_SentEval(NLINet_SimpleBiLSTM_model,vocabulary,text_field,device)
# Out:
# 2021-04-22 21:09:37,396 : **************Start SentEval evaluation*******************
# 2021-04-22 21:09:37,398 : ***** Transfer task : CR *****
#
#
# 2021-04-22 21:09:37,411 : Generating sentence embeddings
# 2021-04-22 21:09:39,551 : Generated sentence embeddings
# 2021-04-22 21:09:39,553 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:10:15,685 : Best param found at split 1: l2reg = 0.0001                 with score 78.27
# 2021-04-22 21:10:47,617 : Best param found at split 2: l2reg = 1e-05                 with score 79.31
# 2021-04-22 21:11:20,064 : Best param found at split 3: l2reg = 0.0001                 with score 78.66
# 2021-04-22 21:11:52,583 : Best param found at split 4: l2reg = 1e-05                 with score 78.86
# 2021-04-22 21:12:24,525 : Best param found at split 5: l2reg = 0.0001                 with score 78.75
# 2021-04-22 21:12:55,649 : Best param found at split 6: l2reg = 1e-05                 with score 78.66
# 2021-04-22 21:13:28,294 : Best param found at split 7: l2reg = 1e-05                 with score 79.04
# 2021-04-22 21:13:59,347 : Best param found at split 8: l2reg = 1e-05                 with score 78.61
# 2021-04-22 21:14:31,864 : Best param found at split 9: l2reg = 1e-05                 with score 78.93
# 2021-04-22 21:15:04,560 : Best param found at split 10: l2reg = 0.001                 with score 78.66
# 2021-04-22 21:15:05,160 : Dev acc : 78.77 Test acc : 77.86
#
# 2021-04-22 21:15:05,161 : ***** Transfer task : MR *****
#
#
# 2021-04-22 21:15:05,199 : Generating sentence embeddings
# 2021-04-22 21:15:11,679 : Generated sentence embeddings
# 2021-04-22 21:15:11,681 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:16:37,703 : Best param found at split 1: l2reg = 0.0001                 with score 73.41
# 2021-04-22 21:18:01,913 : Best param found at split 2: l2reg = 1e-05                 with score 73.57
# 2021-04-22 21:19:29,839 : Best param found at split 3: l2reg = 0.0001                 with score 73.26
# 2021-04-22 21:20:55,822 : Best param found at split 4: l2reg = 1e-05                 with score 73.01
# 2021-04-22 21:22:18,580 : Best param found at split 5: l2reg = 0.0001                 with score 73.43
# 2021-04-22 21:23:45,114 : Best param found at split 6: l2reg = 1e-05                 with score 73.12
# 2021-04-22 21:25:07,243 : Best param found at split 7: l2reg = 1e-05                 with score 72.86
# 2021-04-22 21:26:34,791 : Best param found at split 8: l2reg = 1e-05                 with score 72.95
# 2021-04-22 21:28:00,570 : Best param found at split 9: l2reg = 1e-05                 with score 73.59
# 2021-04-22 21:29:30,026 : Best param found at split 10: l2reg = 0.0001                 with score 73.07
# 2021-04-22 21:29:31,947 : Dev acc : 73.23 Test acc : 72.24
#
# 2021-04-22 21:29:31,949 : ***** Transfer task : SUBJ *****
#
#
# 2021-04-22 21:29:31,989 : Generating sentence embeddings
# 2021-04-22 21:29:38,879 : Generated sentence embeddings
# 2021-04-22 21:29:38,880 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:31:12,133 : Best param found at split 1: l2reg = 1e-05                 with score 88.66
# 2021-04-22 21:32:50,606 : Best param found at split 2: l2reg = 1e-05                 with score 88.91
# 2021-04-22 21:34:23,553 : Best param found at split 3: l2reg = 1e-05                 with score 89.01
# 2021-04-22 21:35:58,303 : Best param found at split 4: l2reg = 0.0001                 with score 88.68
# 2021-04-22 21:37:32,515 : Best param found at split 5: l2reg = 0.0001                 with score 88.9
# 2021-04-22 21:39:00,627 : Best param found at split 6: l2reg = 1e-05                 with score 88.72
# 2021-04-22 21:40:33,511 : Best param found at split 7: l2reg = 1e-05                 with score 88.82
# 2021-04-22 21:42:10,021 : Best param found at split 8: l2reg = 0.0001                 with score 88.46
# 2021-04-22 21:43:41,720 : Best param found at split 9: l2reg = 0.0001                 with score 88.58
# 2021-04-22 21:45:17,562 : Best param found at split 10: l2reg = 0.0001                 with score 88.61
# 2021-04-22 21:45:19,562 : Dev acc : 88.74 Test acc : 88.06
#
# 2021-04-22 21:45:19,564 : ***** Transfer task : MPQA *****
#
#
# 2021-04-22 21:45:19,582 : Generating sentence embeddings
# 2021-04-22 21:45:20,763 : Generated sentence embeddings
# 2021-04-22 21:45:20,765 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:46:45,473 : Best param found at split 1: l2reg = 1e-05                 with score 85.49
# 2021-04-22 21:48:06,459 : Best param found at split 2: l2reg = 0.001                 with score 85.2
# 2021-04-22 21:49:33,548 : Best param found at split 3: l2reg = 0.0001                 with score 85.07
# 2021-04-22 21:50:58,710 : Best param found at split 4: l2reg = 0.0001                 with score 84.99
# 2021-04-22 21:52:25,001 : Best param found at split 5: l2reg = 1e-05                 with score 85.21
# 2021-04-22 21:53:48,216 : Best param found at split 6: l2reg = 0.0001                 with score 85.09
# 2021-04-22 21:55:13,452 : Best param found at split 7: l2reg = 0.001                 with score 85.22
# 2021-04-22 21:56:33,239 : Best param found at split 8: l2reg = 1e-05                 with score 85.17
# 2021-04-22 21:58:01,856 : Best param found at split 9: l2reg = 1e-05                 with score 85.11
# 2021-04-22 21:59:27,149 : Best param found at split 10: l2reg = 1e-05                 with score 85.3
# 2021-04-22 21:59:29,644 : Dev acc : 85.18 Test acc : 84.64
#
# 2021-04-22 21:59:29,646 : ***** Transfer task : SST Binary classification *****
#
#
# 2021-04-22 21:59:29,778 : Computing embedding for train
# 2021-04-22 21:59:50,136 : Computed train embeddings
# 2021-04-22 21:59:50,137 : Computing embedding for dev
# 2021-04-22 21:59:50,660 : Computed dev embeddings
# 2021-04-22 21:59:50,661 : Computing embedding for test
# 2021-04-22 21:59:51,699 : Computed test embeddings
# 2021-04-22 21:59:51,700 : Training pytorch-MLP-nhid0-adam-bs256 with standard validation..
# 2021-04-22 22:00:45,193 : [('reg:1e-05', 79.24), ('reg:0.0001', 79.01), ('reg:0.001', 78.21), ('reg:0.01', 75.8)]
# 2021-04-22 22:00:45,194 : Validation : best param found is reg = 1e-05 with score             79.24
# 2021-04-22 22:00:45,195 : Evaluating...
# 2021-04-22 22:01:00,387 :
# Dev acc : 79.24 Test acc : 78.47 for             SST Binary classification
#
# 2021-04-22 22:01:00,391 : ***** Transfer task : TREC *****
#
#
# 2021-04-22 22:01:02,093 : Computed train embeddings
# 2021-04-22 22:01:02,226 : Computed test embeddings
# 2021-04-22 22:01:02,227 : Training pytorch-MLP-nhid0-adam-bs256 with 10-fold cross-validation
# 2021-04-22 22:02:08,620 : [('reg:1e-05', 71.08), ('reg:0.0001', 71.15), ('reg:0.001', 69.63), ('reg:0.01', 63.61)]
# 2021-04-22 22:02:08,621 : Cross-validation : best param found is reg = 0.0001             with score 71.15
# 2021-04-22 22:02:08,622 : Evaluating...
# 2021-04-22 22:02:10,490 :
# Dev acc : 71.15 Test acc : 73.2             for TREC
#
# 2021-04-22 22:02:10,493 : ***** Transfer task : SICK-Relatedness*****
#
#
# 2021-04-22 22:02:10,523 : Computing embedding for train
# 2021-04-22 22:02:13,215 : Computed train embeddings
# 2021-04-22 22:02:13,216 : Computing embedding for dev
# 2021-04-22 22:02:13,538 : Computed dev embeddings
# 2021-04-22 22:02:13,539 : Computing embedding for test
# 2021-04-22 22:02:16,448 : Computed test embeddings
# 2021-04-22 22:02:42,838 : Dev : Pearson 0.8679719846919707
# 2021-04-22 22:02:42,839 : Test : Pearson 0.8603855872775802 Spearman 0.7983445680999613 MSE 0.2652340741689829                        for SICK Relatedness
#
# 2021-04-22 22:02:42,842 : ***** Transfer task : SICK-Entailment*****
#
#
# 2021-04-22 22:02:42,879 : Computing embedding for train
# 2021-04-22 22:02:45,571 : Computed train embeddings
# 2021-04-22 22:02:45,572 : Computing embedding for dev
# 2021-04-22 22:02:45,894 : Computed dev embeddings
# 2021-04-22 22:02:45,894 : Computing embedding for test
# 2021-04-22 22:02:48,826 : Computed test embeddings
# 2021-04-22 22:02:49,098 : Training pytorch-MLP-nhid0-adam-bs256 with standard validation..
# 2021-04-22 22:02:53,553 : [('reg:1e-05', 83.8), ('reg:0.0001', 83.8), ('reg:0.001', 83.8), ('reg:0.01', 81.4)]
# 2021-04-22 22:02:53,554 : Validation : best param found is reg = 1e-05 with score             83.8
# 2021-04-22 22:02:53,554 : Evaluating...
# 2021-04-22 22:02:54,725 :
# Dev acc : 83.8 Test acc : 83.21 for                        SICK entailment
#
# 2021-04-22 22:02:54,728 : ***** Transfer task : MRPC *****
#
#
# 2021-04-22 22:02:54,768 : Computing embedding for train
# 2021-04-22 22:02:59,793 : Computed train embeddings
# 2021-04-22 22:02:59,794 : Computing embedding for test
# 2021-04-22 22:03:01,922 : Computed test embeddings
# 2021-04-22 22:03:02,088 : Training pytorch-MLP-nhid0-adam-bs256 with 10-fold cross-validation
# 2021-04-22 22:03:38,298 : [('reg:1e-05', 72.55), ('reg:0.0001', 72.06), ('reg:0.001', 71.37), ('reg:0.01', 69.9)]
# 2021-04-22 22:03:38,299 : Cross-validation : best param found is reg = 1e-05             with score 72.55
# 2021-04-22 22:03:38,299 : Evaluating...
# 2021-04-22 22:03:39,292 : Dev acc : 72.55 Test acc 73.39; Test F1 82.02 for MRPC.
#
# 2021-04-22 22:03:39,294 : ***** Transfer task : STS14 *****
#
#
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/sts.py:42: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/sts.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# 2021-04-22 22:03:39,659 : deft-forum : pearson = 0.1952, spearman = 0.1830
# 2021-04-22 22:03:40,072 : deft-news : pearson = 0.5844, spearman = 0.5420
# 2021-04-22 22:03:40,527 : headlines : pearson = 0.5304, spearman = 0.4974
# 2021-04-22 22:03:41,061 : images : pearson = 0.7966, spearman = 0.7535
# 2021-04-22 22:03:41,541 : OnWN : pearson = 0.5452, spearman = 0.5994
# 2021-04-22 22:03:42,162 : tweet-news : pearson = 0.5968, spearman = 0.5455
# 2021-04-22 22:03:42,163 : ALL (weighted average) : Pearson = 0.5640,             Spearman = 0.5445
# 2021-04-22 22:03:42,163 : ALL (average) : Pearson = 0.5414,             Spearman = 0.5201
#
# 2021-04-22 22:03:42,164 : SentEval evalution_results:
# 2021-04-22 22:03:42,164 : ********************SentEval evaluation completed*************************
