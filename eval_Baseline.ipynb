# %%
import os
from torchtext import data
import torch
import torch.nn as nn
import torch.optim as optim
import senteval
import numpy as np
from torchtext.datasets import SNLI
from torchtext.vocab import GloVe
from model.NLINet import NLINet
import logging
logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.DEBUG)

# %%
# build dataset and word embedding

glove = GloVe(name='840B', dim=300, cache="./dataset/.vector_cache")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#set up fields
text_field = data.Field(tokenize='spacy',tokenizer_language="en_core_web_sm",
                        lower=True,include_lengths=True,batch_first=True)
label_field = data.Field(sequential=False)

train, val, test = SNLI.splits(text_field, label_field, root="./dataset/.data")

# build vocab
text_field.build_vocab(train, vectors=glove)
label_field.build_vocab(train)
vocabulary = text_field.vocab

train_iters,val_iters,test_iters = data.BucketIterator.splits(
    (train, val, test), batch_size=128, device=device)
# Out:
# 2021-04-22 21:08:13,494 : Loading vectors from ../my_job/dataset/.vector_cache/glove.840B.300d.txt.pt
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/example.py:13: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/iterator.py:48: UserWarning: BucketIterator class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)

# %%
def eval_SentEval(NLINet_model,vocabulary,text_field,device):
    logging.info("**************Start SentEval evaluation*******************")
    def batcher(params, batch):
        batch = [sent if sent != [] else ['.'] for sent in batch]
        torch.cuda.empty_cache()
        with torch.no_grad():
            batch_pad = params.text_field.process(batch,device=params.device)
            batch, batch_len = batch_pad
            embedding_glove = params.NLINet_model.embedding(batch)
            embeddings_sents = params.NLINet_model.encoder_model(embedding_glove,batch_len)
            embeddings_sents = embeddings_sents.cpu().numpy()
        return embeddings_sents

    # parameters
    params = {'task_path': "./SentEval/data", 'usepytorch': True, 'kfold': 10,'batch_size': 256}
    params['classifier'] = {'nhid': 0, 'optim': 'adam', 'batch_size': 256,
                            'tenacity': 5, 'epoch_size': 4}

    params["word2id"] = vocabulary.stoi
    params["word_vec"] = vocabulary.vectors
    params["wvec_dim"] = 300
    params["NLINet_model"] = NLINet_model
    params["text_field"] = text_field
    params["device"] = device

    se = senteval.engine.SE(params, batcher)
    transfer_tasks = ['CR','MR', 'SUBJ', 'MPQA', 'SST2', 'TREC',
                      'SICKRelatedness', 'SICKEntailment', 'MRPC', 'STS14']

    results = se.eval(transfer_tasks)

    logging.info("SentEval evalution_results:", results)
    logging.info('********************SentEval evaluation completed*************************')
    
def eval_SNLI(NLINet_model,test_iters):
    logging.info("***********************Start SNLI evaluation*******************************")
    eval_acc = 0
    for j, batch in enumerate(test_iters):
        hypothesis = batch.hypothesis
        premise = batch.premise
        labels = batch.label-1

        # forward + backward + optimize
        preds = NLINet_model(hypothesis, premise)
        eval_acc += binary_acc(preds, labels).item()

    eval_acc = eval_acc/len(test_iters.dataset.examples)
    logging.info(f"SNLI evalution_accuracy: {eval_acc:.5f}")
    logging.info("***************SNLI evaluation completed********************")
    
def binary_acc(preds, y):
    """
    get accuracy
    """
    preds = torch.argmax(preds, dim=1)
    correct = torch.eq(preds, y).float()
    acc = correct.sum()
    return acc

# %%
# load Baseline model 
Baseline_model_path = os.path.join('./output/Baseline', "models", 'best_checkpoint.pkl')
NLINet_Baseline_model=torch.load(Baseline_model_path)
NLINet_Baseline_model.eval()
# Out:
# NLINet(
#   (embedding): Embedding(33635, 300)
#   (encoder_model): Baseline()
#   (classifier): Sequential(
#     (0): Linear(in_features=1200, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
# evaluate Baseline model by SNLI
eval_SNLI(NLINet_Baseline_model,test_iters)
# Out:
# 2021-04-22 21:09:11,384 : ***********************Start SNLI evaluation*******************************
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/batch.py:23: UserWarning: Batch class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# 2021-04-22 21:09:12,111 : SNLI evalution_accuracy: 0.65493
# 2021-04-22 21:09:12,112 : ***************SNLI evaluation completed********************

# %%
# evaluate Baseline model by SentEval
eval_SentEval(NLINet_Baseline_model,vocabulary,text_field,device)
# Out:
# 2021-04-22 21:09:12,116 : **************Start SentEval evaluation*******************
# 2021-04-22 21:09:12,117 : ***** Transfer task : CR *****
#
#
# 2021-04-22 21:09:12,129 : Generating sentence embeddings
# 2021-04-22 21:09:12,165 : Generated sentence embeddings
# 2021-04-22 21:09:12,166 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:10:04,817 : Best param found at split 1: l2reg = 1e-05                 with score 77.8
# 2021-04-22 21:10:47,885 : Best param found at split 2: l2reg = 1e-05                 with score 78.16
# 2021-04-22 21:11:32,130 : Best param found at split 3: l2reg = 0.0001                 with score 78.13
# 2021-04-22 21:12:15,561 : Best param found at split 4: l2reg = 0.0001                 with score 77.66
# 2021-04-22 21:12:59,606 : Best param found at split 5: l2reg = 0.001                 with score 77.89
# 2021-04-22 21:13:43,550 : Best param found at split 6: l2reg = 0.0001                 with score 77.69
# 2021-04-22 21:14:28,628 : Best param found at split 7: l2reg = 1e-05                 with score 78.22
# 2021-04-22 21:15:19,331 : Best param found at split 8: l2reg = 1e-05                 with score 78.1
# 2021-04-22 21:16:00,857 : Best param found at split 9: l2reg = 1e-05                 with score 77.28
# 2021-04-22 21:16:47,226 : Best param found at split 10: l2reg = 0.001                 with score 77.69
# 2021-04-22 21:16:48,096 : Dev acc : 77.86 Test acc : 76.72
#
# 2021-04-22 21:16:48,097 : ***** Transfer task : MR *****
#
#
# 2021-04-22 21:16:48,134 : Generating sentence embeddings
# 2021-04-22 21:16:48,268 : Generated sentence embeddings
# 2021-04-22 21:16:48,270 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:18:24,700 : Best param found at split 1: l2reg = 1e-05                 with score 74.77
# 2021-04-22 21:19:59,286 : Best param found at split 2: l2reg = 1e-05                 with score 75.0
# 2021-04-22 21:21:31,810 : Best param found at split 3: l2reg = 0.0001                 with score 74.45
# 2021-04-22 21:23:06,820 : Best param found at split 4: l2reg = 1e-05                 with score 74.7
# 2021-04-22 21:24:34,871 : Best param found at split 5: l2reg = 1e-05                 with score 74.61
# 2021-04-22 21:26:14,574 : Best param found at split 6: l2reg = 0.0001                 with score 74.58
# 2021-04-22 21:27:46,412 : Best param found at split 7: l2reg = 1e-05                 with score 74.39
# 2021-04-22 21:29:20,044 : Best param found at split 8: l2reg = 1e-05                 with score 74.43
# 2021-04-22 21:31:02,291 : Best param found at split 9: l2reg = 0.001                 with score 74.8
# 2021-04-22 21:32:39,275 : Best param found at split 10: l2reg = 0.0001                 with score 74.4
# 2021-04-22 21:32:42,403 : Dev acc : 74.61 Test acc : 74.12
#
# 2021-04-22 21:32:42,404 : ***** Transfer task : SUBJ *****
#
#
# 2021-04-22 21:32:42,442 : Generating sentence embeddings
# 2021-04-22 21:32:42,571 : Generated sentence embeddings
# 2021-04-22 21:32:42,572 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:34:25,022 : Best param found at split 1: l2reg = 1e-05                 with score 89.5
# 2021-04-22 21:36:09,292 : Best param found at split 2: l2reg = 0.0001                 with score 89.74
# 2021-04-22 21:37:54,524 : Best param found at split 3: l2reg = 0.0001                 with score 89.68
# 2021-04-22 21:39:36,323 : Best param found at split 4: l2reg = 1e-05                 with score 89.62
# 2021-04-22 21:41:22,828 : Best param found at split 5: l2reg = 0.0001                 with score 90.08
# 2021-04-22 21:43:02,772 : Best param found at split 6: l2reg = 1e-05                 with score 89.77
# 2021-04-22 21:44:46,115 : Best param found at split 7: l2reg = 1e-05                 with score 89.79
# 2021-04-22 21:46:29,562 : Best param found at split 8: l2reg = 1e-05                 with score 89.7
# 2021-04-22 21:48:11,942 : Best param found at split 9: l2reg = 1e-05                 with score 89.67
# 2021-04-22 21:50:01,295 : Best param found at split 10: l2reg = 1e-05                 with score 89.71
# 2021-04-22 21:50:03,037 : Dev acc : 89.73 Test acc : 88.95
#
# 2021-04-22 21:50:03,040 : ***** Transfer task : MPQA *****
#
#
# 2021-04-22 21:50:03,058 : Generating sentence embeddings
# 2021-04-22 21:50:03,133 : Generated sentence embeddings
# 2021-04-22 21:50:03,135 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:51:32,953 : Best param found at split 1: l2reg = 1e-05                 with score 85.31
# 2021-04-22 21:52:57,252 : Best param found at split 2: l2reg = 1e-05                 with score 84.8
# 2021-04-22 21:54:25,131 : Best param found at split 3: l2reg = 0.0001                 with score 84.55
# 2021-04-22 21:55:53,161 : Best param found at split 4: l2reg = 1e-05                 with score 84.66
# 2021-04-22 21:57:19,032 : Best param found at split 5: l2reg = 0.0001                 with score 85.02
# 2021-04-22 21:58:49,084 : Best param found at split 6: l2reg = 0.0001                 with score 84.8
# 2021-04-22 22:00:34,659 : Best param found at split 7: l2reg = 1e-05                 with score 84.86
# 2021-04-22 22:02:06,776 : Best param found at split 8: l2reg = 1e-05                 with score 84.97
# 2021-04-22 22:03:36,211 : Best param found at split 9: l2reg = 1e-05                 with score 84.86
# 2021-04-22 22:04:45,575 : Best param found at split 10: l2reg = 0.0001                 with score 84.95
# 2021-04-22 22:04:47,280 : Dev acc : 84.88 Test acc : 84.29
#
# 2021-04-22 22:04:47,283 : ***** Transfer task : SST Binary classification *****
#
#
# 2021-04-22 22:04:47,404 : Computing embedding for train
# 2021-04-22 22:04:49,359 : Computed train embeddings
# 2021-04-22 22:04:49,360 : Computing embedding for dev
# 2021-04-22 22:04:49,387 : Computed dev embeddings
# 2021-04-22 22:04:49,388 : Computing embedding for test
# 2021-04-22 22:04:49,408 : Computed test embeddings
# 2021-04-22 22:04:49,408 : Training pytorch-MLP-nhid0-adam-bs256 with standard validation..
# 2021-04-22 22:05:42,233 : [('reg:1e-05', 77.98), ('reg:0.0001', 77.64), ('reg:0.001', 77.18), ('reg:0.01', 75.34)]
# 2021-04-22 22:05:42,234 : Validation : best param found is reg = 1e-05 with score             77.98
# 2021-04-22 22:05:42,235 : Evaluating...
# 2021-04-22 22:05:55,509 :
# Dev acc : 77.98 Test acc : 78.31 for             SST Binary classification
#
# 2021-04-22 22:05:55,510 : ***** Transfer task : TREC *****
#
#
# 2021-04-22 22:05:55,595 : Computed train embeddings
# 2021-04-22 22:05:55,601 : Computed test embeddings
# 2021-04-22 22:05:55,602 : Training pytorch-MLP-nhid0-adam-bs256 with 10-fold cross-validation
# 2021-04-22 22:07:01,996 : [('reg:1e-05', 64.97), ('reg:0.0001', 65.28), ('reg:0.001', 64.12), ('reg:0.01', 58.09)]
# 2021-04-22 22:07:01,997 : Cross-validation : best param found is reg = 0.0001             with score 65.28
# 2021-04-22 22:07:01,998 : Evaluating...
# 2021-04-22 22:07:03,276 :
# Dev acc : 65.28 Test acc : 67.2             for TREC
#
# 2021-04-22 22:07:03,277 : ***** Transfer task : SICK-Relatedness*****
#
#
# 2021-04-22 22:07:03,306 : Computing embedding for train
# 2021-04-22 22:07:03,371 : Computed train embeddings
# 2021-04-22 22:07:03,371 : Computing embedding for dev
# 2021-04-22 22:07:03,380 : Computed dev embeddings
# 2021-04-22 22:07:03,381 : Computing embedding for test
# 2021-04-22 22:07:03,452 : Computed test embeddings
# 2021-04-22 22:07:39,561 : Dev : Pearson 0.7947533662284079
# 2021-04-22 22:07:39,561 : Test : Pearson 0.7966633213411105 Spearman 0.7094390969302603 MSE 0.37191124150236776                        for SICK Relatedness
#
# 2021-04-22 22:07:39,562 : ***** Transfer task : SICK-Entailment*****
#
#
# 2021-04-22 22:07:39,598 : Computing embedding for train
# 2021-04-22 22:07:39,662 : Computed train embeddings
# 2021-04-22 22:07:39,663 : Computing embedding for dev
# 2021-04-22 22:07:39,672 : Computed dev embeddings
# 2021-04-22 22:07:39,673 : Computing embedding for test
# 2021-04-22 22:07:39,740 : Computed test embeddings
# 2021-04-22 22:07:39,755 : Training pytorch-MLP-nhid0-adam-bs256 with standard validation..
# 2021-04-22 22:07:45,324 : [('reg:1e-05', 76.8), ('reg:0.0001', 76.6), ('reg:0.001', 75.6), ('reg:0.01', 66.2)]
# 2021-04-22 22:07:45,324 : Validation : best param found is reg = 1e-05 with score             76.8
# 2021-04-22 22:07:45,325 : Evaluating...
# 2021-04-22 22:07:46,850 :
# Dev acc : 76.8 Test acc : 76.7 for                        SICK entailment
#
# 2021-04-22 22:07:46,852 : ***** Transfer task : MRPC *****
#
#
# 2021-04-22 22:07:46,891 : Computing embedding for train
# 2021-04-22 22:07:46,983 : Computed train embeddings
# 2021-04-22 22:07:46,984 : Computing embedding for test
# 2021-04-22 22:07:47,023 : Computed test embeddings
# 2021-04-22 22:07:47,031 : Training pytorch-MLP-nhid0-adam-bs256 with 10-fold cross-validation
# 2021-04-22 22:08:17,344 : [('reg:1e-05', 71.27), ('reg:0.0001', 71.34), ('reg:0.001', 70.88), ('reg:0.01', 70.44)]
# 2021-04-22 22:08:17,345 : Cross-validation : best param found is reg = 0.0001             with score 71.34
# 2021-04-22 22:08:17,346 : Evaluating...
# 2021-04-22 22:08:18,903 : Dev acc : 71.34 Test acc 71.07; Test F1 80.27 for MRPC.
#
# 2021-04-22 22:08:18,905 : ***** Transfer task : STS14 *****
#
#
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/sts.py:42: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/sts.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# 2021-04-22 22:08:18,996 : deft-forum : pearson = 0.2635, spearman = 0.3161
# 2021-04-22 22:08:19,035 : deft-news : pearson = 0.5880, spearman = 0.5979
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/utils.py:39: RuntimeWarning: invalid value encountered in float_scalars
# 2021-04-22 22:08:19,124 : headlines : pearson = 0.5131, spearman = 0.5151
# 2021-04-22 22:08:19,205 : images : pearson = 0.6357, spearman = 0.6178
# 2021-04-22 22:08:19,306 : OnWN : pearson = 0.5153, spearman = 0.5860
# 2021-04-22 22:08:19,397 : tweet-news : pearson = 0.4895, spearman = 0.5046
# 2021-04-22 22:08:19,398 : ALL (weighted average) : Pearson = 0.5094,             Spearman = 0.5305
# 2021-04-22 22:08:19,399 : ALL (average) : Pearson = 0.5008,             Spearman = 0.5229
#
# 2021-04-22 22:08:19,399 : SentEval evalution_results:
# 2021-04-22 22:08:19,399 : ********************SentEval evaluation completed*************************
