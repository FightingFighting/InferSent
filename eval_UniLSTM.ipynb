# %%
import os
from torchtext import data
import torch
import torch.nn as nn
import torch.optim as optim
import senteval
import numpy as np
from torchtext.datasets import SNLI
from torchtext.vocab import GloVe
from model.NLINet import NLINet
import logging
logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.DEBUG)

# %%
# build dataset and word embedding

glove = GloVe(name='840B', dim=300, cache="./dataset/.vector_cache")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#set up fields
text_field = data.Field(tokenize='spacy',tokenizer_language="en_core_web_sm",
                        lower=True,include_lengths=True,batch_first=True)
label_field = data.Field(sequential=False)

train, val, test = SNLI.splits(text_field, label_field, root="./dataset/.data")

# build vocab
text_field.build_vocab(train, vectors=glove)
label_field.build_vocab(train)
vocabulary = text_field.vocab

train_iters,val_iters,test_iters = data.BucketIterator.splits(
    (train, val, test), batch_size=128, device=device)
# Out:
# 2021-04-22 21:08:27,372 : Loading vectors from ../my_job/dataset/.vector_cache/glove.840B.300d.txt.pt
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/field.py:150: UserWarning: Field class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/example.py:13: UserWarning: Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('Example class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.', UserWarning)
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/iterator.py:48: UserWarning: BucketIterator class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)

# %%
def eval_SentEval(NLINet_model,vocabulary,text_field,device):
    logging.info("**************Start SentEval evaluation*******************")
    def batcher(params, batch):
        batch = [sent if sent != [] else ['.'] for sent in batch]
        torch.cuda.empty_cache()
        with torch.no_grad():
            batch_pad = params.text_field.process(batch,device=params.device)
            batch, batch_len = batch_pad
            embedding_glove = params.NLINet_model.embedding(batch)
            embeddings_sents = params.NLINet_model.encoder_model(embedding_glove,batch_len)
            embeddings_sents = embeddings_sents.cpu().numpy()
        return embeddings_sents

    # parameters
    params = {'task_path': "./SentEval/data", 'usepytorch': True, 'kfold': 10,'batch_size': 256}
    params['classifier'] = {'nhid': 0, 'optim': 'adam', 'batch_size': 256,
                            'tenacity': 5, 'epoch_size': 4}

    params["word2id"] = vocabulary.stoi
    params["word_vec"] = vocabulary.vectors
    params["wvec_dim"] = 300
    params["NLINet_model"] = NLINet_model
    params["text_field"] = text_field
    params["device"] = device

    se = senteval.engine.SE(params, batcher)
    transfer_tasks = ['CR','MR', 'SUBJ', 'MPQA', 'SST2', 'TREC',
                      'SICKRelatedness', 'SICKEntailment', 'MRPC', 'STS14']

    results = se.eval(transfer_tasks)

    logging.info("SentEval evalution_results:", results)
    logging.info('********************SentEval evaluation completed*************************')
    
def eval_SNLI(NLINet_model,test_iters):
    logging.info("***********************Start SNLI evaluation*******************************")
    eval_acc = 0
    for j, batch in enumerate(test_iters):
        hypothesis = batch.hypothesis
        premise = batch.premise
        labels = batch.label-1

        # forward + backward + optimize
        preds = NLINet_model(hypothesis, premise)
        eval_acc += binary_acc(preds, labels).item()

    eval_acc = eval_acc/len(test_iters.dataset.examples)
    logging.info(f"SNLI evalution_accuracy: {eval_acc:.5f}")
    logging.info("***************SNLI evaluation completed********************")
    
def binary_acc(preds, y):
    """
    get accuracy
    """
    preds = torch.argmax(preds, dim=1)
    correct = torch.eq(preds, y).float()
    acc = correct.sum()
    return acc

# %%
# load UniLSTM model 
UniLSTM_model_path = os.path.join('./output/UniLSTM', "models", 'best_checkpoint.pkl')
NLINet_UniLSTM_model=torch.load(UniLSTM_model_path)
NLINet_UniLSTM_model.eval()
# Out:
# NLINet(
#   (embedding): Embedding(33635, 300)
#   (encoder_model): UniLSTM(
#     (lstm): LSTM(300, 2048, batch_first=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=3, bias=True)
#   )
# )

# %%
# evaluate UniLSTM model by SNLI
eval_SNLI(NLINet_UniLSTM_model,test_iters)
# Out:
# 2021-04-22 21:09:23,991 : ***********************Start SNLI evaluation*******************************
# /opt/conda/envs/infersent/lib/python3.6/site-packages/torchtext/data/batch.py:23: UserWarning: Batch class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.
#   warnings.warn('{} class will be retired soon and moved to torchtext.legacy. Please see the most recent release notes for further information.'.format(self.__class__.__name__), UserWarning)
# 2021-04-22 21:09:27,824 : SNLI evalution_accuracy: 0.80588
# 2021-04-22 21:09:27,825 : ***************SNLI evaluation completed********************

# %%
# evaluate UniLSTM model by SentEval
eval_SentEval(NLINet_UniLSTM_model,vocabulary,text_field,device)
# Out:
# 2021-04-22 21:09:27,830 : **************Start SentEval evaluation*******************
# 2021-04-22 21:09:27,831 : ***** Transfer task : CR *****
#
#
# 2021-04-22 21:09:27,845 : Generating sentence embeddings
# 2021-04-22 21:09:28,870 : Generated sentence embeddings
# 2021-04-22 21:09:28,872 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:10:09,734 : Best param found at split 1: l2reg = 1e-05                 with score 77.6
# 2021-04-22 21:10:38,718 : Best param found at split 2: l2reg = 0.0001                 with score 78.16
# 2021-04-22 21:11:08,814 : Best param found at split 3: l2reg = 0.0001                 with score 78.01
# 2021-04-22 21:11:36,755 : Best param found at split 4: l2reg = 1e-05                 with score 77.39
# 2021-04-22 21:12:06,571 : Best param found at split 5: l2reg = 0.0001                 with score 77.72
# 2021-04-22 21:12:35,973 : Best param found at split 6: l2reg = 1e-05                 with score 77.49
# 2021-04-22 21:13:03,296 : Best param found at split 7: l2reg = 1e-05                 with score 77.87
# 2021-04-22 21:13:32,708 : Best param found at split 8: l2reg = 1e-05                 with score 77.9
# 2021-04-22 21:14:02,446 : Best param found at split 9: l2reg = 0.001                 with score 78.11
# 2021-04-22 21:14:31,907 : Best param found at split 10: l2reg = 1e-05                 with score 77.96
# 2021-04-22 21:14:32,460 : Dev acc : 77.82 Test acc : 75.95
#
# 2021-04-22 21:14:32,462 : ***** Transfer task : MR *****
#
#
# 2021-04-22 21:14:32,498 : Generating sentence embeddings
# 2021-04-22 21:14:35,815 : Generated sentence embeddings
# 2021-04-22 21:14:35,817 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:16:01,821 : Best param found at split 1: l2reg = 1e-05                 with score 71.9
# 2021-04-22 21:17:24,566 : Best param found at split 2: l2reg = 1e-05                 with score 72.24
# 2021-04-22 21:18:46,184 : Best param found at split 3: l2reg = 1e-05                 with score 71.84
# 2021-04-22 21:20:09,945 : Best param found at split 4: l2reg = 1e-05                 with score 72.2
# 2021-04-22 21:21:29,730 : Best param found at split 5: l2reg = 1e-05                 with score 72.19
# 2021-04-22 21:22:50,140 : Best param found at split 6: l2reg = 1e-05                 with score 72.0
# 2021-04-22 21:24:10,247 : Best param found at split 7: l2reg = 1e-05                 with score 72.11
# 2021-04-22 21:25:28,704 : Best param found at split 8: l2reg = 1e-05                 with score 71.83
# 2021-04-22 21:26:46,515 : Best param found at split 9: l2reg = 0.0001                 with score 72.32
# 2021-04-22 21:28:06,732 : Best param found at split 10: l2reg = 1e-05                 with score 71.93
# 2021-04-22 21:28:09,143 : Dev acc : 72.06 Test acc : 71.5
#
# 2021-04-22 21:28:09,146 : ***** Transfer task : SUBJ *****
#
#
# 2021-04-22 21:28:09,189 : Generating sentence embeddings
# 2021-04-22 21:28:12,726 : Generated sentence embeddings
# 2021-04-22 21:28:12,727 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:29:48,483 : Best param found at split 1: l2reg = 0.0001                 with score 85.49
# 2021-04-22 21:31:22,922 : Best param found at split 2: l2reg = 0.0001                 with score 85.78
# 2021-04-22 21:33:02,095 : Best param found at split 3: l2reg = 1e-05                 with score 85.63
# 2021-04-22 21:34:35,027 : Best param found at split 4: l2reg = 1e-05                 with score 85.91
# 2021-04-22 21:36:06,567 : Best param found at split 5: l2reg = 0.0001                 with score 85.84
# 2021-04-22 21:37:40,695 : Best param found at split 6: l2reg = 0.0001                 with score 85.67
# 2021-04-22 21:39:08,489 : Best param found at split 7: l2reg = 1e-05                 with score 85.39
# 2021-04-22 21:40:40,260 : Best param found at split 8: l2reg = 0.0001                 with score 85.66
# 2021-04-22 21:42:13,618 : Best param found at split 9: l2reg = 1e-05                 with score 85.68
# 2021-04-22 21:43:50,201 : Best param found at split 10: l2reg = 1e-05                 with score 85.51
# 2021-04-22 21:43:52,192 : Dev acc : 85.66 Test acc : 84.97
#
# 2021-04-22 21:43:52,194 : ***** Transfer task : MPQA *****
#
#
# 2021-04-22 21:43:52,212 : Generating sentence embeddings
# 2021-04-22 21:43:52,829 : Generated sentence embeddings
# 2021-04-22 21:43:52,831 : Training pytorch-MLP-nhid0-adam-bs256 with (inner) 10-fold cross-validation
# 2021-04-22 21:45:16,424 : Best param found at split 1: l2reg = 1e-05                 with score 85.45
# 2021-04-22 21:46:42,317 : Best param found at split 2: l2reg = 1e-05                 with score 85.22
# 2021-04-22 21:48:04,833 : Best param found at split 3: l2reg = 0.0001                 with score 84.87
# 2021-04-22 21:49:22,872 : Best param found at split 4: l2reg = 1e-05                 with score 84.83
# 2021-04-22 21:50:45,346 : Best param found at split 5: l2reg = 1e-05                 with score 85.05
# 2021-04-22 21:52:08,802 : Best param found at split 6: l2reg = 1e-05                 with score 85.0
# 2021-04-22 21:53:30,324 : Best param found at split 7: l2reg = 0.0001                 with score 85.16
# 2021-04-22 21:54:51,209 : Best param found at split 8: l2reg = 1e-05                 with score 85.08
# 2021-04-22 21:56:09,990 : Best param found at split 9: l2reg = 1e-05                 with score 85.2
# 2021-04-22 21:57:35,221 : Best param found at split 10: l2reg = 0.0001                 with score 85.13
# 2021-04-22 21:57:37,875 : Dev acc : 85.1 Test acc : 84.42
#
# 2021-04-22 21:57:37,877 : ***** Transfer task : SST Binary classification *****
#
#
# 2021-04-22 21:57:38,006 : Computing embedding for train
# 2021-04-22 21:57:49,304 : Computed train embeddings
# 2021-04-22 21:57:49,305 : Computing embedding for dev
# 2021-04-22 21:57:49,575 : Computed dev embeddings
# 2021-04-22 21:57:49,576 : Computing embedding for test
# 2021-04-22 21:57:50,109 : Computed test embeddings
# 2021-04-22 21:57:50,110 : Training pytorch-MLP-nhid0-adam-bs256 with standard validation..
# 2021-04-22 21:58:44,824 : [('reg:1e-05', 77.29), ('reg:0.0001', 77.18), ('reg:0.001', 77.06), ('reg:0.01', 75.69)]
# 2021-04-22 21:58:44,825 : Validation : best param found is reg = 1e-05 with score             77.29
# 2021-04-22 21:58:44,825 : Evaluating...
# 2021-04-22 21:59:01,304 :
# Dev acc : 77.29 Test acc : 76.72 for             SST Binary classification
#
# 2021-04-22 21:59:01,307 : ***** Transfer task : TREC *****
#
#
# 2021-04-22 21:59:02,193 : Computed train embeddings
# 2021-04-22 21:59:02,268 : Computed test embeddings
# 2021-04-22 21:59:02,269 : Training pytorch-MLP-nhid0-adam-bs256 with 10-fold cross-validation
# 2021-04-22 22:00:20,281 : [('reg:1e-05', 60.45), ('reg:0.0001', 60.25), ('reg:0.001', 59.67), ('reg:0.01', 54.88)]
# 2021-04-22 22:00:20,282 : Cross-validation : best param found is reg = 1e-05             with score 60.45
# 2021-04-22 22:00:20,283 : Evaluating...
# 2021-04-22 22:00:22,374 :
# Dev acc : 60.45 Test acc : 66.2             for TREC
#
# 2021-04-22 22:00:22,376 : ***** Transfer task : SICK-Relatedness*****
#
#
# 2021-04-22 22:00:22,406 : Computing embedding for train
# 2021-04-22 22:00:23,832 : Computed train embeddings
# 2021-04-22 22:00:23,833 : Computing embedding for dev
# 2021-04-22 22:00:24,006 : Computed dev embeddings
# 2021-04-22 22:00:24,007 : Computing embedding for test
# 2021-04-22 22:00:25,573 : Computed test embeddings
# 2021-04-22 22:00:53,359 : Dev : Pearson 0.8577682713226228
# 2021-04-22 22:00:53,360 : Test : Pearson 0.8541819633851481 Spearman 0.792948362379545 MSE 0.27681197289954396                        for SICK Relatedness
#
# 2021-04-22 22:00:53,363 : ***** Transfer task : SICK-Entailment*****
#
#
# 2021-04-22 22:00:53,401 : Computing embedding for train
# 2021-04-22 22:00:54,842 : Computed train embeddings
# 2021-04-22 22:00:54,843 : Computing embedding for dev
# 2021-04-22 22:00:55,016 : Computed dev embeddings
# 2021-04-22 22:00:55,017 : Computing embedding for test
# 2021-04-22 22:00:56,577 : Computed test embeddings
# 2021-04-22 22:00:56,720 : Training pytorch-MLP-nhid0-adam-bs256 with standard validation..
# 2021-04-22 22:01:02,628 : [('reg:1e-05', 82.6), ('reg:0.0001', 82.8), ('reg:0.001', 83.2), ('reg:0.01', 82.6)]
# 2021-04-22 22:01:02,629 : Validation : best param found is reg = 0.001 with score             83.2
# 2021-04-22 22:01:02,629 : Evaluating...
# 2021-04-22 22:01:03,889 :
# Dev acc : 83.2 Test acc : 82.16 for                        SICK entailment
#
# 2021-04-22 22:01:03,892 : ***** Transfer task : MRPC *****
#
#
# 2021-04-22 22:01:03,931 : Computing embedding for train
# 2021-04-22 22:01:06,576 : Computed train embeddings
# 2021-04-22 22:01:06,577 : Computing embedding for test
# 2021-04-22 22:01:07,703 : Computed test embeddings
# 2021-04-22 22:01:07,780 : Training pytorch-MLP-nhid0-adam-bs256 with 10-fold cross-validation
# 2021-04-22 22:01:47,519 : [('reg:1e-05', 72.94), ('reg:0.0001', 72.69), ('reg:0.001', 72.45), ('reg:0.01', 70.41)]
# 2021-04-22 22:01:47,520 : Cross-validation : best param found is reg = 1e-05             with score 72.94
# 2021-04-22 22:01:47,520 : Evaluating...
# 2021-04-22 22:01:48,651 : Dev acc : 72.94 Test acc 72.52; Test F1 81.34 for MRPC.
#
# 2021-04-22 22:01:48,655 : ***** Transfer task : STS14 *****
#
#
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/sts.py:42: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /opt/conda/envs/infersent/lib/python3.6/site-packages/SentEval-0.1.0-py3.6.egg/senteval/sts.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# 2021-04-22 22:01:48,871 : deft-forum : pearson = 0.3922, spearman = 0.4189
# 2021-04-22 22:01:49,099 : deft-news : pearson = 0.5814, spearman = 0.5419
# 2021-04-22 22:01:49,365 : headlines : pearson = 0.4894, spearman = 0.4573
# 2021-04-22 22:01:49,671 : images : pearson = 0.8024, spearman = 0.7563
# 2021-04-22 22:01:49,954 : OnWN : pearson = 0.6077, spearman = 0.6514
# 2021-04-22 22:01:50,302 : tweet-news : pearson = 0.5455, spearman = 0.4958
# 2021-04-22 22:01:50,303 : ALL (weighted average) : Pearson = 0.5826,             Spearman = 0.5658
# 2021-04-22 22:01:50,304 : ALL (average) : Pearson = 0.5698,             Spearman = 0.5536
#
# 2021-04-22 22:01:50,305 : SentEval evalution_results:
# 2021-04-22 22:01:50,305 : ********************SentEval evaluation completed*************************
